# %%
import numpy as np
import pandas as pd
import seaborn as sns
import pandas.testing as pd_testing
#import pandas.util.testing as rm
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/Mathematics/Downloads/dataset (1)/dataset/Boston.csv")
df.head()
# Out:
#      CRIM     ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
df.describe()
# Out:
#             CRIM           ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       PRICE
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
sns.distplot(df["RAD"])
# Out:
# C:\Users\Mathematics\AppData\Local\Temp\ipykernel_5544\2547040940.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["RAD"])
# <Axes: xlabel='RAD', ylabel='Density'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
target_y=df['PRICE']
features_x=df.drop('PRICE',axis=1,inplace=False)
features_x.head()
# Out:
#      CRIM     ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
train_x,test_x,train_y,test_y=train_test_split(features_x,target_y,test_size=0.2)

# %%
test_x.shape
# Out:
# (102, 13)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
print('Co-efficients:',model.coef_)
print('Intercept:',model.intercept_)
# Out:
# Co-efficients: [-1.09188959e-01  5.04292460e-02 -7.82301374e-03  1.73808359e+00
#  -1.48967995e+01  3.73641073e+00 -1.89199462e-02 -1.42618508e+00
#   2.68385046e-01 -1.19986787e-02 -1.00063354e+00  8.15816210e-03
#  -4.41133487e-01]
# Intercept: 37.20861931009481

# %%
predicted_y=model.predict(test_x)

# %%
predicted_y.shape
# Out:
# (102,)

# %%
test_y.shape
# Out:
# (102,)

# %%
from sklearn.metrics import r2_score
print("accuracy:",r2_score(test_y,predicted_y))
# Out:
# accuracy: 0.6834848004884317

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pickle

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(df[['ZN']], df['PRICE'], test_size=0.3, random_state=109)

# %%
#Creating the model
linearRegr =  LinearRegression()
linearRegr.fit(X_train, y_train)
y_pred = linearRegr.predict(X_test)

# %%
y_pred
# Out:
# array([20.7840758 , 31.52958563, 20.7840758 , 20.7840758 , 20.7840758 ,
#        33.54436872, 20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 ,
#        20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 , 32.87277436,
#        32.87277436, 22.46306171, 20.7840758 , 23.47045326, 20.7840758 ,
#        20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 ,
#        31.52958563, 25.48523635, 20.7840758 , 20.7840758 , 20.7840758 ,
#        20.7840758 , 20.7840758 , 20.7840758 , 23.47045326, 20.7840758 ,
#        24.14204762, 23.47045326, 20.7840758 , 20.7840758 , 20.7840758 ,
#        20.7840758 , 30.85799126, 20.7840758 , 20.7840758 , 20.7840758 ,
#        20.7840758 , 20.7840758 , 26.15683072, 25.48523635, 20.7840758 ,
#        20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 ,
#        20.7840758 , 20.7840758 , 20.7840758 , 26.15683072, 20.7840758 ,
#        20.7840758 , 31.52958563, 20.7840758 , 20.7840758 , 26.15683072,
#        20.7840758 , 20.7840758 , 23.47045326, 20.7840758 , 20.7840758 ,
#        26.15683072, 24.14204762, 32.87277436, 26.82842508, 20.7840758 ,
#        20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 ,
#        20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 ,
#        20.7840758 , 20.7840758 , 25.35091748, 20.7840758 , 20.7840758 ,
#        20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 ,
#        20.7840758 , 26.82842508, 20.7840758 , 20.7840758 , 28.84320817,
#        20.7840758 , 20.7840758 , 20.7840758 , 33.54436872, 20.7840758 ,
#        20.7840758 , 24.54500424, 28.84320817, 23.739091  , 20.7840758 ,
#        20.7840758 , 20.7840758 , 23.60477213, 20.7840758 , 23.47045326,
#        24.14204762, 22.46306171, 20.7840758 , 25.21659861, 22.46306171,
#        20.7840758 , 20.7840758 , 20.7840758 , 20.7840758 , 23.47045326,
#        20.7840758 , 20.7840758 , 20.7840758 , 31.52958563, 20.7840758 ,
#        20.7840758 , 22.46306171, 20.7840758 , 28.17161381, 20.7840758 ,
#        20.7840758 , 20.7840758 , 20.7840758 , 23.47045326, 20.7840758 ,
#        20.7840758 , 20.7840758 , 31.52958563, 20.7840758 , 20.7840758 ,
#        24.81364199, 33.54436872, 20.7840758 , 20.7840758 , 20.7840758 ,
#        20.7840758 , 20.7840758 ])

# %%
from sklearn.metrics import r2_score
print(r2_score(y_pred, y_test))
# Out:
# -4.736963545720888

# %%
#Saving the Model
pickle_out = open("linearRegr_windows_new.pkl", "wb") 
pickle.dump(linearRegr, pickle_out) 
pickle_out.close()

# %%
pwd
# Out:
# 'C:\\Users\\Mathematics\\Desktop\\web app'
